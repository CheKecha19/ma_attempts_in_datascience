# %%
import pandas as pd
import numpy as np
# Рисовать графики сразу же
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.use('ggplot')  # Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  # Размер картинок

# %%
# импортируем данные из диска
fixed_df = pd.read_csv('C:/Users/Andrey/YandexDisk/pitonchik/datasets/corona1.csv',  # Это то, куда вы скачали файл
                       sep=';', encoding='latin1',
                       parse_dates=['Date'], dayfirst=True,
                       index_col='Date')
fixed_df[:15]
# Out:
#                                   Region                 Federal District  \
# Date
# 2020-03-06                  Altai region        Siberian Federal District
# 2020-03-06                   Amur region     Far Eastern Federal District
# 2020-03-06             Arhangelsk region    Northwestern Federal District
# 2020-03-06              Astrakhan region        Southern Federal District
# 2020-03-06               Belgorod region         Central Federal District
# 2020-03-06                Bryansk region         Central Federal District
# 2020-03-06               Vladimir region         Central Federal District
# 2020-03-06              Volgograd region        Southern Federal District
# 2020-03-06                Vologda Region    Northwestern Federal District
# 2020-03-06               Voronezh region         Central Federal District
# 2020-03-06      Jewish Autonomous Region     Far Eastern Federal District
# 2020-03-06              Zabaykalsky Krai     Far Eastern Federal District
# 2020-03-06                Ivanovo region         Central Federal District
# 2020-03-06                Irkutsk region        Siberian Federal District
# 2020-03-06  Kabardino-Balkarian Republic  North Caucasus Federal District
#
#             Cases  Deaths
# Date
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN
# 2020-03-06    NaN     NaN

# %%
fixed_df['Deaths'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fixed_df.plot(figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fixed_df['Region'].value_counts()
# Out:
# Ryazan Oblast                      115
# Jewish Autonomous Region           115
# Perm region                        115
# Belgorod region                    115
# Republic of Kalmykia               115
#                                   ...
# Northwestern Federal District       22
# Siberian Federal District           20
# Southern Federal District           16
# North Caucasus Federal District     14
# Ural federal district               12
# Name: Region, Length: 93, dtype: int64

# %%
# Out:
# <AxesSubplot:>
